# %% [markdown]
# # Pandas
#
# ## Installing Packages

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    ---------- ----------------------------- 2.6/9.7 MB 10.2 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.7 MB 11.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.7 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 10.8 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Basics

# %%
pd.Series([10, 20, 30, 40, 50, 'abc'])
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5    abc
# dtype: object

# %%
a = pd.Series([10, 20, 30, 40, 50,])
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.name = "numbers"
s.name
# Out:
# 'numbers'

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: numbers, dtype: int64

# %% [markdown]
# ## Indexing
