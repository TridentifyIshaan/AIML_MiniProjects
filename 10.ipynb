# %% [markdown]
# Use the given data to build a neural network with two hidden layers with each having three nodes. Also, plot the epoch vs loss diagram for 50 epochs.
#
# ![M113.PNG](attachment:M113.PNG)
