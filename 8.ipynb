# %% [markdown]
# # Installing Packages

# %%
# %pip install pandas tensorflow keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import tensorflow as tf
import keras

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Reading train and test data

# %%
train_data = pd.read_csv('datasets/fashion-mnist/train.csv')

# %% [markdown]
# ## Creating validation data from test data

# %%
# Class names
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Read test data
test_data = pd.read_csv('datasets/fashion-mnist/test.csv')

# Creating validation data from test data
val_data = test_data.iloc[:5000,:]
test_data = test_data.iloc[5000:,:]

# %% [markdown]
# ## Fetching the labels

# %%
train_labels = train_data.label
val_labels = val_data.label
test_labels = test_data.label

# %% [markdown]
# ## Reshaping training & validation data

# %%
train_images = train_data.iloc[:,1:].values.reshape(train_data.shape[0], 28, 28)
val_images = val_data.iloc[:,1:].values.reshape(val_data.shape[0], 28, 28)

# %% [markdown]
# ## Scaling data in the range of 0-1

# %% [markdown]
# train_images = train_images/255.0
# val_images = val_images/255.0

# %% [markdown]
# # Building different variants of Neural Network

# %% [markdown]
# ## Case 1
#
# > Building a neural network with one hidden layer having one neuron and with the absence of a non-linear activation function

# %%
# Defining multi-layer perceptron model with 1 hidden layer having 1 neuron
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)), # Perform conversion of higher dimensional data (here, 2-D) to 1-D data.
    keras.layers.Dense(1, activation=tf.keras.activations.linear), # Hidden layer with 1 neuron and linear activation function
    keras.layers.Dense(10, activation=tf.keras.activations.linear) # Output layer with linear activation function 
])                                                   
# Defining parameters like optimizer, loss function and evaluating metric
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(), 
              metrics=['accuracy'])
model1 = model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# /home/codespace/.python/current/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-06-14 13:33:38.200818: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/5
# 2025-06-14 13:33:38.703162: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 27104448 exceeds 10% of free system memory.
# 251/271 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0993 - loss: nan
# 2025-06-14 13:33:40.092483: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# ...

# %% [markdown]
# ## Case 2
#
# > Build a network with one hidden layer having 10 neurons.

# %%
# Defining multi-layer perceptron model with 1 hidden layer having 10 neurons 
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)), # Perform conversion of higher dimensional data (here, 2-D) to 1-D data.
    keras.layers.Dense(10, activation=tf.keras.activations.linear), # Hidden layer with 10 neurons and linear activation function
    keras.layers.Dense(10, activation=tf.keras.activations.linear) # Output layer with linear activation function 
])
# Defining parameters like optimizer, loss function and evaluating metric
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(), 
              metrics=['accuracy'])
model2 = model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# 2025-06-14 13:33:42.971332: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 27104448 exceeds 10% of free system memory.
# 258/271 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1432 - loss: nan
# 2025-06-14 13:33:43.931259: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1434 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 2/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0988 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 3/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1044 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 4/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1037 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 5/5
# ...

# %% [markdown]
# ## Case 3
#
# > In the previous two cases, our models were performing linear regression due to the linear activation function. Now, let's introduce non-linearity to the above case to make it a classification model and thus classify ten classes.

# %%
# Defining multi-layer perceptron model with 1 hidden layer having 10 neurons with non-linearity
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)), # Perform conversion of higher dimensional data (here, 2-D) to 1-D data.
    keras.layers.Dense(10, activation=tf.nn.relu), # Hidden layer with 10 neurons and ReLU activation function
    keras.layers.Dense(10, activation=tf.nn.softmax) # Output layer with softmax activation function 
])
# Defining parameters like optimizer, loss function and evaluating metric
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(), 
              metrics=['accuracy'])
model3 = model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# 2025-06-14 13:33:46.775796: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 27104448 exceeds 10% of free system memory.
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1128 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 2/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1049 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 3/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1004 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 4/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1004 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 5/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1031 - loss: nan - val_accuracy: 0.1004 - val_loss: nan

# %% [markdown]
# ## Case 4
#
# > Let us try to increase the number of hidden layers. This time we will use 3 hidden layers, each with 10 neurons and lastly accompanied by a non-linear activation function.

# %%
# Defining multi-layer perceptron model with 3 hidden layer having 10 neurons each and with non-linearity
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)), # Perform conversion of higher dimensional data (here, 2-D) to 1-D data.
    keras.layers.Dense(10, activation=tf.nn.relu), # Hidden layer with 10 neurons and ReLU activation function
    keras.layers.Dense(10, activation=tf.nn.relu), # Hidden layer with 10 neurons and ReLU activation function
    keras.layers.Dense(10, activation=tf.nn.relu), # Hidden layer with 10 neurons and ReLU activation function
    keras.layers.Dense(10, activation=tf.nn.softmax) # Output layer with softmax activation function 
])
# Defining parameters like optimizer, loss function and evaluating metric
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])
model4 = model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1670 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 2/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1015 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 3/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1008 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 4/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1076 - loss: nan - val_accuracy: 0.1004 - val_loss: nan
# Epoch 5/5
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1011 - loss: nan - val_accuracy: 0.1004 - val_loss: nan

# %% [markdown]
# As we can observe, there is a slight improvement in the validation accuracy, 85.76%. We can build an optimum network by tuning each hyperparameter.
#
# The table below summarizes the above results:
#
# ![M18.PNG](attachment:M18.PNG)
